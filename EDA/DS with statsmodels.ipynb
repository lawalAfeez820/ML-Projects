# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split

# %%
raw_data=pd.read_csv("HousingData.csv")
raw_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
raw_data=raw_data.dropna()
raw_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
raw_data=raw_data.drop_duplicates()

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     394 non-null    float64
#  1   ZN       394 non-null    float64
#  2   INDUS    394 non-null    float64
#  3   CHAS     394 non-null    float64
#  4   NOX      394 non-null    float64
#  5   RM       394 non-null    float64
#  6   AGE      394 non-null    float64
#  7   DIS      394 non-null    float64
#  8   RAD      394 non-null    int64
#  9   TAX      394 non-null    int64
#  10  PTRATIO  394 non-null    float64
#  11  B        394 non-null    float64
#  12  LSTAT    394 non-null    float64
#  13  MEDV     394 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 46.2 KB

# %%
del raw_data["B"]

# %%
raw_data=raw_data.rename(columns={"CRIM":"crimeRatePerCapita", "ZN":"landOver25k_sqrt",
                         "INDUS":"non-retailLandProptn","CHAS":"riverDummy",
                          "NOX":"nitriOxide_pp10m","RM":"AvgNo.RoomsPerDwelling",
                         "AGE":"ProptnOwnerOccupied","DIS":"weightedDist",
                         "RAD":"radialHighwaysAccess","TAX":"propTaxRate_per10k",
                         "PTRATIO":"pupilTeacherRatio","LSTAT":"pctLowerStatus",
                         "MEDV":"medianValue_Ks"})

# %%
raw_data
# Out:
#      crimeRatePerCapita  landOver25k_sqrt  non-retailLandProptn  riverDummy  \
# 0               0.00632              18.0                  2.31         0.0
# 1               0.02731               0.0                  7.07         0.0
# 2               0.02729               0.0                  7.07         0.0
# 3               0.03237               0.0                  2.18         0.0
# 5               0.02985               0.0                  2.18         0.0
# ..                  ...               ...                   ...         ...
# 499             0.17783               0.0                  9.69         0.0
# 500             0.22438               0.0                  9.69         0.0
# 502             0.04527               0.0                 11.93         0.0
# 503             0.06076               0.0                 11.93         0.0
# 504             0.10959               0.0                 11.93         0.0
#
# ...

# %%
y=raw_data.loc[:,["crimeRatePerCapita"]]
y
# Out:
#      crimeRatePerCapita
# 0               0.00632
# 1               0.02731
# 2               0.02729
# 3               0.03237
# 5               0.02985
# ..                  ...
# 499             0.17783
# 500             0.22438
# 502             0.04527
# 503             0.06076
# 504             0.10959
#
# [394 rows x 1 columns]

# %%
x=raw_data.drop("crimeRatePerCapita", axis=1)
x
# Out:
#      landOver25k_sqrt  non-retailLandProptn  riverDummy  nitriOxide_pp10m  \
# 0                18.0                  2.31         0.0             0.538
# 1                 0.0                  7.07         0.0             0.469
# 2                 0.0                  7.07         0.0             0.469
# 3                 0.0                  2.18         0.0             0.458
# 5                 0.0                  2.18         0.0             0.458
# ..                ...                   ...         ...               ...
# 499               0.0                  9.69         0.0             0.585
# 500               0.0                  9.69         0.0             0.585
# 502               0.0                 11.93         0.0             0.573
# 503               0.0                 11.93         0.0             0.573
# 504               0.0                 11.93         0.0             0.573
#
#      AvgNo.RoomsPerDwelling  ProptnOwnerOccupied  weightedDist  \
# ...

# %%
seed=10
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=seed)

# %%
train_data=pd.concat([x_train,y_train],axis=1)

# %%
test_data=pd.concat([x_test,y_test],axis=1)

# %%
x_val=raw_data[["medianValue_Ks"]]

# %%
x_val
# Out:
#      medianValue_Ks
# 0              24.0
# 1              21.6
# 2              34.7
# 3              33.4
# 5              28.7
# ..              ...
# 499            17.5
# 500            16.8
# 502            20.6
# 503            23.9
# 504            22.0
#
# [394 rows x 1 columns]

# %%
linearModel=smf.ols(formula="crimeRatePerCapita~medianValue_Ks",
                   data=train_data)

# %%
linearModelResult=linearModel.fit()

# %%
linearModelResult.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     crimeRatePerCapita   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     58.38
# Date:                Wed, 23 Mar 2022   Prob (F-statistic):           3.09e-13
# Time:                        15:20:33   Log-Likelihood:                -1053.8
# No. Observations:                 295   AIC:                             2112.
# Df Residuals:                     293   BIC:                             2119.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
